# %% [markdown]
# # Using Dropout to fight overfitting
#
# **Goal:** In this notebook you will learn how you can use dropout layers as a very easy way to fight overfitting. You will download the cifar10 dataset which contains quite small images (32x32x3) of 10 classes. The data is from the Canadian Institute For Advanced Research. You will plot examples of the images with the class label below. Note that because the images are so small it's not always very easy to recoginse which of the ten classes is on the iamge, even as a human. After loading the dataset you will train two Convolutional neural networks to predict the the test dataset.
# The first Convolutional neural network will have no dropout layers.
# The second neural network will use dropout layers in the fully connected part of the network.
#
# Finall, you will see that dropout during training is a very easy way to prevent overfitting and even to improve the accuracy!
#
# **Usage:** The idea of the notebook is that you try to understand the provided code by running it, checking the output and playing with it by slightly changing the code and rerunning it.
#
# **Dataset:** You work with the Cifar10 dataset. You have 60'000 32x32 pixel color images of 10 classes ("airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck")
#
# **Content:**
# * Load the Cifar10 dataset
# * Plot a random example of each class label
# * Normalize the data to be in the range from -1 and 1
# * Define and fit a Convolutional neural network without any dropout layers
# * Define and fit a Convolutional neural network with dropout layers in the fully connected part
# * Compare the loss and accuracy curves of the two models
#
# | [open in colab](https://colab.research.google.com/github/tensorchiefs/dl_book/blob/master/chapter_06/nb_ch06_05.ipynb)

# %%
import tensorflow as tf
try: #If running in colab 
    import google.colab
    IN_COLAB = True 
except:
    IN_COLAB = False
if (not tf.__version__.startswith('2')): #Checking if tf 2.0 is installed
    if IN_COLAB: #If running in colab install tf 2.0
        # !pip install tensorflow-gpu==2.0.0-alpha0
        # !pip install tfp-nightly==0.7.0-dev20190511
    print('Please install tensorflow 2.0 to run this notebook')
print('Tensorflow version: ',tf.__version__, ' running in colab?: ', IN_COLAB)
# Out:
# Tensorflow version:  2.0.0-alpha0  running in colab?:  True

# %% [markdown]
# #### Imports

# %%
# load required libraries:
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('default')

import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Convolution2D, MaxPooling2D, Flatten , Activation, Dropout
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### Load, plot and normalize the data
#
# In the next cell you will load the Cifar10 dataset, 50'000 images are in the training set and 10'000 are in the test dataset.
# You will plot one random example of each label, as you can see the images are really small. After the ploting you normalize the images which are in the range from 0 to 255 to be in the range of -1 to 1. Finally you can convert the lables into the one hot encoding.

# %%
from tensorflow.keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

labels=np.array(["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"])
#sample image of each label
plt.figure(figsize=(15,15))
for i in range(0,len(np.unique(y_train))):
    rmd=np.random.choice(np.where(y_train==i)[0],1)
    plt.subplot(1,10,i+1)
    img=x_train[rmd]
    plt.imshow(img[0,:,:,:])
    plt.title(labels[i]+" "+np.str(y_train[rmd][0]))


X_train=((x_train / 255)-0.5)*2 # normalize the data into a range from -1 to 1
Y_train=tensorflow.keras.utils.to_categorical(y_train,10) # one-hot encoding

X_test=((x_test / 255)-0.5)*2   # normalize the data into a range from -1 to 1
Y_test=tensorflow.keras.utils.to_categorical(y_test,10) # one-hot encoding

# %%
print(X_train.shape)
print(Y_train.shape)

print(X_test.shape)
print(Y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)
# (10000, 32, 32, 3)
# (10000, 10)

# %% [markdown]
# ## Define and fit a CNN without dropout layers
#
# In the next few cells you will define and train a CNN to classify the images into the 10 classes. You will use a network with 2 Convolution blocks followed by a Maxpooling layer. After the feature extraction part you will use 2 fully connected layers before classifying the image into one of the 10 classes. You can lookup the hyperparameters of the CNN in the cell below.

# %%
# here you define hyperparameter of the CNN
batch_size = 128
img_rows, img_cols = 32, 32
kernel_size = (3, 3)
input_shape = (img_rows, img_cols, 3)
pool_size = (2, 2)

# %%
nb_classes = 10

# define CNN with 2 convolution blocks and 2 fully connected layers
model = Sequential()

model.add(Convolution2D(16,kernel_size,padding='same',input_shape=input_shape))
model.add(Activation('relu'))
model.add(Convolution2D(16,kernel_size,padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Convolution2D(32,kernel_size,padding='same'))
model.add(Activation('relu'))
model.add(Convolution2D(32,kernel_size,padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=pool_size))


model.add(Flatten())
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dense(nb_classes))
model.add(Activation('softmax'))

# compile model and intitialize weights
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 16)        448
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               204900
# _________________________________________________________________
# activation_4 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_5 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 232,666
# Trainable params: 232,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1=model.fit(X_train, Y_train,validation_data=(X_test,Y_test), batch_size=128,epochs=30,verbose=1)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 6s 122us/sample - loss: 1.5250 - accuracy: 0.4512 - val_loss: 1.2361 - val_accuracy: 0.5520
# Epoch 2/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 1.1143 - accuracy: 0.6021 - val_loss: 1.0324 - val_accuracy: 0.6355
# Epoch 3/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.9366 - accuracy: 0.6667 - val_loss: 0.9239 - val_accuracy: 0.6735
# Epoch 4/30
# 50000/50000 [==============================] - 4s 79us/sample - loss: 0.8211 - accuracy: 0.7112 - val_loss: 0.8689 - val_accuracy: 0.6990
# Epoch 5/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.7315 - accuracy: 0.7443 - val_loss: 0.8387 - val_accuracy: 0.7102
# Epoch 6/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.6583 - accuracy: 0.7689 - val_loss: 0.8375 - val_accuracy: 0.7051
# Epoch 7/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.5916 - accuracy: 0.7928 - val_loss: 0.8342 - val_accuracy: 0.7154
# Epoch 8/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.5353 - accuracy: 0.8132 - val_loss: 0.8751 - val_accuracy: 0.7117
# Epoch 9/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.4726 - accuracy: 0.8349 - val_loss: 0.8771 - val_accuracy: 0.7170
# Epoch 10/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.4234 - accuracy: 0.8510 - val_loss: 0.9389 - val_accuracy: 0.7150
# Epoch 11/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.3733 - accuracy: 0.8693 - val_loss: 0.9912 - val_accuracy: 0.7152
# Epoch 12/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.3349 - accuracy: 0.8810 - val_loss: 1.0238 - val_accuracy: 0.7083
# Epoch 13/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.2814 - accuracy: 0.9027 - val_loss: 1.0641 - val_accuracy: 0.7083
# Epoch 14/30
# 50000/50000 [==============================] - 4s 79us/sample - loss: 0.2543 - accuracy: 0.9094 - val_loss: 1.1517 - val_accuracy: 0.7090
# Epoch 15/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.2136 - accuracy: 0.9233 - val_loss: 1.2205 - val_accuracy: 0.7108
# Epoch 16/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.1912 - accuracy: 0.9318 - val_loss: 1.2986 - val_accuracy: 0.7026
# Epoch 17/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.1606 - accuracy: 0.9440 - val_loss: 1.4100 - val_accuracy: 0.7086
# Epoch 18/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.1474 - accuracy: 0.9479 - val_loss: 1.5161 - val_accuracy: 0.7034
# Epoch 19/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.1427 - accuracy: 0.9487 - val_loss: 1.5686 - val_accuracy: 0.7030
# Epoch 20/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.1076 - accuracy: 0.9621 - val_loss: 1.7822 - val_accuracy: 0.6969
# Epoch 21/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.1087 - accuracy: 0.9604 - val_loss: 1.7953 - val_accuracy: 0.6961
# Epoch 22/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.1060 - accuracy: 0.9624 - val_loss: 1.8627 - val_accuracy: 0.6973
# Epoch 23/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.0953 - accuracy: 0.9654 - val_loss: 1.8987 - val_accuracy: 0.6960
# Epoch 24/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.0984 - accuracy: 0.9650 - val_loss: 1.9212 - val_accuracy: 0.7048
# Epoch 25/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.0899 - accuracy: 0.9674 - val_loss: 2.2985 - val_accuracy: 0.6817
# Epoch 26/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.0843 - accuracy: 0.9705 - val_loss: 2.1818 - val_accuracy: 0.6975
# Epoch 27/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.0772 - accuracy: 0.9721 - val_loss: 2.1263 - val_accuracy: 0.6977
# Epoch 28/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.0846 - accuracy: 0.9702 - val_loss: 2.0811 - val_accuracy: 0.6967
# Epoch 29/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.0668 - accuracy: 0.9767 - val_loss: 2.2088 - val_accuracy: 0.6993
# Epoch 30/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.0787 - accuracy: 0.9725 - val_loss: 2.2248 - val_accuracy: 0.6970

# %% [markdown]
# ## Define and fit a CNN with dropout layers in the fully connected part
#
# In the next few cells you will define and train a CNN to classify the images into the 10 classes. You will use the same network with one small change. This time you add dropout layers after the fully connected layers, you will use a dropout rate of 0.5. This means that in trainig, half of the nodes in the fully conncted part are randomly deleted at each update step.

# %%
nb_classes = 10

# define CNN with 2 convolution blocks and 2 fully connected layers
model = Sequential()

model.add(Convolution2D(16,kernel_size,padding='same',input_shape=input_shape))
model.add(Activation('relu'))
model.add(Convolution2D(16,kernel_size,padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Convolution2D(32,kernel_size,padding='same'))
model.add(Activation('relu'))
model.add(Convolution2D(32,kernel_size,padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=pool_size))


model.add(Flatten())
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(nb_classes))
model.add(Activation('softmax'))

# compile model and intitialize weights
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 16)        448
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# activation_8 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# activation_9 (Activation)    (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# activation_10 (Activation)   (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               204900
# _________________________________________________________________
# activation_11 (Activation)   (None, 100)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_12 (Activation)   (None, 100)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_13 (Activation)   (None, 10)                0
# =================================================================
# Total params: 232,666
# Trainable params: 232,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2=model.fit(X_train, Y_train,validation_data=(X_test,Y_test), batch_size=128,epochs=30,verbose=1)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 5s 91us/sample - loss: 1.8798 - accuracy: 0.2930 - val_loss: 1.4900 - val_accuracy: 0.4724
# Epoch 2/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 1.4459 - accuracy: 0.4716 - val_loss: 1.1543 - val_accuracy: 0.5979
# Epoch 3/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 1.2663 - accuracy: 0.5493 - val_loss: 1.0571 - val_accuracy: 0.6294
# Epoch 4/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 1.1628 - accuracy: 0.5910 - val_loss: 0.9758 - val_accuracy: 0.6578
# Epoch 5/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 1.0912 - accuracy: 0.6228 - val_loss: 0.9690 - val_accuracy: 0.6733
# Epoch 6/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 1.0294 - accuracy: 0.6434 - val_loss: 0.9067 - val_accuracy: 0.6858
# Epoch 7/30
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.9778 - accuracy: 0.6643 - val_loss: 0.9047 - val_accuracy: 0.6924
# Epoch 8/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.9456 - accuracy: 0.6753 - val_loss: 0.8630 - val_accuracy: 0.7023
# Epoch 9/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.9053 - accuracy: 0.6881 - val_loss: 0.8498 - val_accuracy: 0.7111
# Epoch 10/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.8752 - accuracy: 0.6997 - val_loss: 0.8745 - val_accuracy: 0.7096
# Epoch 11/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.8477 - accuracy: 0.7082 - val_loss: 0.8529 - val_accuracy: 0.7099
# Epoch 12/30
# 50000/50000 [==============================] - 4s 84us/sample - loss: 0.8333 - accuracy: 0.7137 - val_loss: 0.8160 - val_accuracy: 0.7237
# Epoch 13/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.8012 - accuracy: 0.7251 - val_loss: 0.8184 - val_accuracy: 0.7244
# Epoch 14/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.7795 - accuracy: 0.7311 - val_loss: 0.7940 - val_accuracy: 0.7300
# Epoch 15/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.7669 - accuracy: 0.7352 - val_loss: 0.8155 - val_accuracy: 0.7297
# Epoch 16/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.7503 - accuracy: 0.7421 - val_loss: 0.7954 - val_accuracy: 0.7341
# Epoch 17/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.7298 - accuracy: 0.7459 - val_loss: 0.7936 - val_accuracy: 0.7343
# Epoch 18/30
# 50000/50000 [==============================] - 4s 80us/sample - loss: 0.7174 - accuracy: 0.7533 - val_loss: 0.8325 - val_accuracy: 0.7199
# Epoch 19/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.6963 - accuracy: 0.7587 - val_loss: 0.7967 - val_accuracy: 0.7328
# Epoch 20/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.6911 - accuracy: 0.7623 - val_loss: 0.7982 - val_accuracy: 0.7382
# Epoch 21/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.6739 - accuracy: 0.7685 - val_loss: 0.8060 - val_accuracy: 0.7369
# Epoch 22/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.6595 - accuracy: 0.7724 - val_loss: 0.8122 - val_accuracy: 0.7340
# Epoch 23/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.6457 - accuracy: 0.7750 - val_loss: 0.8460 - val_accuracy: 0.7251
# Epoch 24/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.6428 - accuracy: 0.7773 - val_loss: 0.8056 - val_accuracy: 0.7397
# Epoch 25/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.6300 - accuracy: 0.7786 - val_loss: 0.8412 - val_accuracy: 0.7321
# Epoch 26/30
# 50000/50000 [==============================] - 4s 82us/sample - loss: 0.6226 - accuracy: 0.7831 - val_loss: 0.8079 - val_accuracy: 0.7385
# Epoch 27/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.6069 - accuracy: 0.7873 - val_loss: 0.8207 - val_accuracy: 0.7377
# Epoch 28/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.6020 - accuracy: 0.7906 - val_loss: 0.8400 - val_accuracy: 0.7376
# Epoch 29/30
# 50000/50000 [==============================] - 4s 81us/sample - loss: 0.5900 - accuracy: 0.7961 - val_loss: 0.8156 - val_accuracy: 0.7399
# Epoch 30/30
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.5807 - accuracy: 0.7980 - val_loss: 0.8439 - val_accuracy: 0.7359

# %% [markdown]
# ## Plotting the loss and accuracy curves
# In the next few cells you plot the loss and accuray curves of the both models, the one without the dropout layers and the one with the dropout layers in the fully connected part.

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.ylim(0, 1)
plt.title('model accuracy (no dropout)')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(2,2,2)
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss (no dropout)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
plt.ylim([0,2])


plt.subplot(2,2,3)
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.ylim(0, 1)
plt.title('model accuracy (with dropout)')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(2,2,4)
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss (with dropout)')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
plt.ylim([0,2])
plt.show()

# %% [markdown]
# **As you can see the model with the dropout layers has a much nice learning curve. You can see a decreasing traning and validation loss and the curves are not very far apart. In the model without dropout you see overfitting; the validation loss starts to increase again after 7 epochs and the training loss is close to zero after 30 epochs. Note that in addition to the prevention of overfitting, you also even gain better classification accuracy ~73% compared to around ~71% without dropout.**
