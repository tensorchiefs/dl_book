# %%
import tensorflow as tf
try: #If running in colab 
    import google.colab
    IN_COLAB = True 
except:
    IN_COLAB = False
if (not tf.__version__.startswith('2')): #Checking if tf 2.0 is installed
    if IN_COLAB: #If running in colab install tf 2.0
        # !pip install tensorflow-gpu==2.0.0-alpha0
        # !pip install pip install tfp-nightly==0.7.0-dev20190511
    print('Please install tensorflow 2.0 to run this notebook')
print('Tensorflow version: ',tf.__version__, ' running in colab?: ', IN_COLAB)
# Out:
# Tensorflow version:  2.0.0-alpha0  running in colab?:  True

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from sklearn.model_selection import train_test_split
import tensorflow_probability as tfp


# %matplotlib inline
plt.style.use('default')

tfd = tfp.distributions
tfb = tfp.bijectors
print("TFP Version", tfp.__version__)
print("TF  Version",tf.__version__)
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# TFP Version 0.7.0
# TF  Version 2.0.0-alpha0

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
labels=np.array(["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"])
#sample image of each label
plt.figure(figsize=(20,20))
for i in range(0,len(np.unique(y_train))):
    rmd=np.random.choice(np.where(y_train==i)[0],1)
    plt.subplot(1,10,i+1)
    img=x_train[rmd]
    plt.imshow(img[0,:,:,:])
    plt.title(labels[i]+" "+np.str(y_train[rmd][0]))

# %%
#we delete all horses of the dataset
y_train_no_horse=np.delete(y_train,np.where(y_train==7)[0])
x_train_no_horse=np.delete(x_train,np.where(y_train==7)[0],axis=0)

# %%
print(y_train_no_horse.shape)
print(x_train_no_horse.shape)
# Out:
# (45000,)
# (45000, 32, 32, 3)

# %%
y_train_no_horse=np.array(pd.get_dummies(y_train_no_horse))
labels_no_horse=np.array(["airplane","automobile","bird","cat","deer","dog","frog","ship","truck"])

# %%
print(y_train_no_horse.shape)
# Out:
# (45000, 9)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train_no_horse, y_train_no_horse, test_size=0.4, random_state=22)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (27000, 32, 32, 3)
# (27000, 9)
# (18000, 32, 32, 3)
# (18000, 9)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
## tf norm
x_train=((x_train/255)-0.5)*2
x_val=((x_val/255)-0.5)*2
x_test=((x_test/255)-0.5)*2

# %% [markdown]
# ## Baseline "normal" CNN

# %%
from tensorflow.keras.layers import Convolution2D,MaxPooling2D,Dropout,Flatten,Dense
from tensorflow.keras import Sequential

model = Sequential()
model.add(Convolution2D(8,kernel_size=(3,3),padding="same", activation = 'relu',input_shape=(32,32,3)))
model.add(Convolution2D(8,kernel_size=(3,3),padding="same", activation = 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Convolution2D(16,kernel_size=(3,3),padding="same", activation = 'relu'))
model.add(Convolution2D(16,kernel_size=(3,3),padding="same", activation = 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(100, activation = 'relu'))
model.add(Dropout((0.5)))
model.add(Dense(9, activation = 'softmax'))

model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_12 (Conv2D)           (None, 32, 32, 8)         224
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 8)         584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 16, 16, 16)        1168
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 16)        2320
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 100)               102500
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 9)                 909
# =================================================================
# Total params: 107,705
# Trainable params: 107,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(x_train, y_train,validation_data=(x_val,y_val), batch_size=128,epochs=30,verbose=1)
#nach  30 epochs overfitting
# Out:
# Train on 27000 samples, validate on 18000 samples
# Epoch 1/30
# 27000/27000 [==============================] - 3s 101us/sample - loss: 1.8043 - accuracy: 0.3214 - val_loss: 1.5368 - val_accuracy: 0.4419
# Epoch 2/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 1.4749 - accuracy: 0.4477 - val_loss: 1.3270 - val_accuracy: 0.5056
# Epoch 3/30
# 27000/27000 [==============================] - 2s 81us/sample - loss: 1.3637 - accuracy: 0.4929 - val_loss: 1.2309 - val_accuracy: 0.5471
# Epoch 4/30
# 27000/27000 [==============================] - 2s 81us/sample - loss: 1.2961 - accuracy: 0.5195 - val_loss: 1.2715 - val_accuracy: 0.5266
# Epoch 5/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 1.2469 - accuracy: 0.5386 - val_loss: 1.1584 - val_accuracy: 0.5791
# Epoch 6/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 1.2120 - accuracy: 0.5509 - val_loss: 1.2031 - val_accuracy: 0.5649
# Epoch 7/30
# 27000/27000 [==============================] - 2s 81us/sample - loss: 1.1731 - accuracy: 0.5691 - val_loss: 1.0967 - val_accuracy: 0.6001
# Epoch 8/30
# 27000/27000 [==============================] - 2s 81us/sample - loss: 1.1298 - accuracy: 0.5823 - val_loss: 1.0995 - val_accuracy: 0.6008
# Epoch 9/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 1.1050 - accuracy: 0.5962 - val_loss: 1.0714 - val_accuracy: 0.6078
# Epoch 10/30
# 27000/27000 [==============================] - 2s 81us/sample - loss: 1.0738 - accuracy: 0.6050 - val_loss: 1.0559 - val_accuracy: 0.6132
# Epoch 11/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 1.0448 - accuracy: 0.6150 - val_loss: 1.0278 - val_accuracy: 0.6271
# Epoch 12/30
# 27000/27000 [==============================] - 2s 81us/sample - loss: 1.0193 - accuracy: 0.6275 - val_loss: 1.0195 - val_accuracy: 0.6282
# Epoch 13/30
# 27000/27000 [==============================] - 2s 83us/sample - loss: 0.9990 - accuracy: 0.6323 - val_loss: 1.0074 - val_accuracy: 0.6339
# Epoch 14/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 0.9808 - accuracy: 0.6422 - val_loss: 1.0097 - val_accuracy: 0.6374
# Epoch 15/30
# 27000/27000 [==============================] - 2s 83us/sample - loss: 0.9553 - accuracy: 0.6505 - val_loss: 1.0300 - val_accuracy: 0.6288
# Epoch 16/30
# 27000/27000 [==============================] - 2s 83us/sample - loss: 0.9303 - accuracy: 0.6529 - val_loss: 0.9873 - val_accuracy: 0.6421
# Epoch 17/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 0.9025 - accuracy: 0.6667 - val_loss: 0.9912 - val_accuracy: 0.6436
# Epoch 18/30
# 27000/27000 [==============================] - 2s 83us/sample - loss: 0.8940 - accuracy: 0.6714 - val_loss: 0.9980 - val_accuracy: 0.6436
# Epoch 19/30
# 27000/27000 [==============================] - 2s 85us/sample - loss: 0.8814 - accuracy: 0.6724 - val_loss: 1.0030 - val_accuracy: 0.6429
# Epoch 20/30
# 27000/27000 [==============================] - 2s 84us/sample - loss: 0.8580 - accuracy: 0.6811 - val_loss: 0.9906 - val_accuracy: 0.6495
# Epoch 21/30
# 27000/27000 [==============================] - 2s 84us/sample - loss: 0.8460 - accuracy: 0.6856 - val_loss: 1.0333 - val_accuracy: 0.6425
# Epoch 22/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 0.8310 - accuracy: 0.6895 - val_loss: 0.9936 - val_accuracy: 0.6514
# Epoch 23/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 0.8156 - accuracy: 0.6973 - val_loss: 0.9851 - val_accuracy: 0.6508
# Epoch 24/30
# 27000/27000 [==============================] - 2s 83us/sample - loss: 0.8090 - accuracy: 0.6983 - val_loss: 1.0105 - val_accuracy: 0.6499
# Epoch 25/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 0.7865 - accuracy: 0.7061 - val_loss: 0.9988 - val_accuracy: 0.6525
# Epoch 26/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 0.7724 - accuracy: 0.7099 - val_loss: 0.9969 - val_accuracy: 0.6561
# Epoch 27/30
# 27000/27000 [==============================] - 2s 83us/sample - loss: 0.7611 - accuracy: 0.7130 - val_loss: 1.0180 - val_accuracy: 0.6480
# Epoch 28/30
# 27000/27000 [==============================] - 2s 82us/sample - loss: 0.7504 - accuracy: 0.7176 - val_loss: 1.0224 - val_accuracy: 0.6569
# Epoch 29/30
# 27000/27000 [==============================] - 2s 81us/sample - loss: 0.7320 - accuracy: 0.7224 - val_loss: 1.0269 - val_accuracy: 0.6533
# Epoch 30/30
# 27000/27000 [==============================] - 2s 84us/sample - loss: 0.7215 - accuracy: 0.7288 - val_loss: 1.0432 - val_accuracy: 0.6492

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylim(0, 1)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
plt.show()

# %% [markdown]
# ## Variational Inference

# %%
kernel_divergence_fn=lambda q, p, _: tfp.distributions.kl_divergence(q, p) / (x_train.shape[0] * 1.0)
model_vi = Sequential()
model_vi.add(tfp.layers.Convolution2DFlipout(8,kernel_size=(3,3),padding="same", activation = 'relu', kernel_divergence_fn=kernel_divergence_fn,input_shape=(32,32,3)))
model_vi.add(tfp.layers.Convolution2DFlipout(8,kernel_size=(3,3),padding="same", activation = 'relu', kernel_divergence_fn=kernel_divergence_fn))
model_vi.add(tf.keras.layers.MaxPooling2D((2,2)))
model_vi.add(tfp.layers.Convolution2DFlipout(16,kernel_size=(3,3),padding="same", activation = 'relu', kernel_divergence_fn=kernel_divergence_fn))
model_vi.add(tfp.layers.Convolution2DFlipout(16,kernel_size=(3,3),padding="same", activation = 'relu', kernel_divergence_fn=kernel_divergence_fn))
model_vi.add(tf.keras.layers.MaxPooling2D((2,2)))
model_vi.add(tf.keras.layers.Flatten())
model_vi.add(tfp.layers.DenseFlipout(100, activation = 'relu', kernel_divergence_fn=kernel_divergence_fn))
model_vi.add(tfp.layers.DenseFlipout(9, activation = 'softmax', kernel_divergence_fn=kernel_divergence_fn))

model_vi.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])
model_vi.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_flipout_8 (Conv2DFlip (None, 32, 32, 8)         440
# _________________________________________________________________
# conv2d_flipout_9 (Conv2DFlip (None, 32, 32, 8)         1160
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_flipout_10 (Conv2DFli (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv2d_flipout_11 (Conv2DFli (None, 16, 16, 16)        4624
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_flipout_4 (DenseFlipou (None, 100)               204900
# _________________________________________________________________
# dense_flipout_5 (DenseFlipou (None, 9)                 1809
# =================================================================
# Total params: 215,253
# Trainable params: 215,253
# Non-trainable params: 0
# _________________________________________________________________

# %%
for i in range(0,5):
  print(model_vi.predict(x_train[0:1])[0])
#we get a different pred at every run!
# Out:
# [0.07391138 0.03170445 0.06204162 0.1508851  0.10165034 0.14898
#  0.1708257  0.14464268 0.11535873]
# [0.11457948 0.08483541 0.06694109 0.11150151 0.07487863 0.13190679
#  0.14851858 0.11540393 0.15143453]
# [0.11764423 0.05539053 0.0601637  0.14930825 0.07000053 0.13178973
#  0.18633617 0.09398743 0.13537946]
# [0.16579384 0.06581009 0.09687789 0.11725284 0.07249661 0.10346472
#  0.10721778 0.146743   0.12434322]
# [0.10067008 0.04777056 0.07058206 0.11026525 0.10453665 0.07871575
#  0.10008033 0.19826913 0.18911028]

# %%
history=model_vi.fit(x_train, y_train,validation_data=(x_val,y_val), batch_size=128,epochs=150,verbose=1)
# need a lot of epochs
# longer training would maybe give some improvement
# Out:
# Train on 27000 samples, validate on 18000 samples
# Epoch 1/150
# 27000/27000 [==============================] - 5s 179us/sample - loss: 11.7543 - accuracy: 0.2396 - val_loss: 11.2292 - val_accuracy: 0.3308
# Epoch 2/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 10.8636 - accuracy: 0.3667 - val_loss: 10.5217 - val_accuracy: 0.4001
# Epoch 3/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 10.2309 - accuracy: 0.4149 - val_loss: 9.9355 - val_accuracy: 0.4334
# Epoch 4/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 9.6683 - accuracy: 0.4463 - val_loss: 9.4156 - val_accuracy: 0.4502
# Epoch 5/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 9.1658 - accuracy: 0.4623 - val_loss: 8.9430 - val_accuracy: 0.4698
# Epoch 6/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 8.7016 - accuracy: 0.4859 - val_loss: 8.5049 - val_accuracy: 0.4849
# Epoch 7/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 8.2640 - accuracy: 0.5026 - val_loss: 8.1149 - val_accuracy: 0.4851
# Epoch 8/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 7.8752 - accuracy: 0.5150 - val_loss: 7.7264 - val_accuracy: 0.5036
# Epoch 9/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 7.5075 - accuracy: 0.5271 - val_loss: 7.3808 - val_accuracy: 0.5164
# Epoch 10/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 7.1697 - accuracy: 0.5389 - val_loss: 7.0659 - val_accuracy: 0.5193
# Epoch 11/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 6.8612 - accuracy: 0.5447 - val_loss: 6.7791 - val_accuracy: 0.5230
# Epoch 12/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 6.5657 - accuracy: 0.5566 - val_loss: 6.5087 - val_accuracy: 0.5328
# Epoch 13/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 6.3010 - accuracy: 0.5628 - val_loss: 6.2524 - val_accuracy: 0.5330
# Epoch 14/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 6.0546 - accuracy: 0.5637 - val_loss: 6.0182 - val_accuracy: 0.5383
# Epoch 15/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 5.8256 - accuracy: 0.5694 - val_loss: 5.8035 - val_accuracy: 0.5463
# Epoch 16/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 5.6151 - accuracy: 0.5786 - val_loss: 5.5992 - val_accuracy: 0.5506
# Epoch 17/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 5.4255 - accuracy: 0.5779 - val_loss: 5.4140 - val_accuracy: 0.5491
# Epoch 18/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 5.2339 - accuracy: 0.5844 - val_loss: 5.2365 - val_accuracy: 0.5521
# Epoch 19/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 5.0624 - accuracy: 0.5914 - val_loss: 5.0858 - val_accuracy: 0.5538
# Epoch 20/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 4.9048 - accuracy: 0.5886 - val_loss: 4.9337 - val_accuracy: 0.5597
# Epoch 21/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 4.7565 - accuracy: 0.5948 - val_loss: 4.7900 - val_accuracy: 0.5601
# Epoch 22/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 4.6173 - accuracy: 0.6014 - val_loss: 4.6570 - val_accuracy: 0.5676
# Epoch 23/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 4.4842 - accuracy: 0.5998 - val_loss: 4.5411 - val_accuracy: 0.5628
# Epoch 24/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 4.3641 - accuracy: 0.6001 - val_loss: 4.4226 - val_accuracy: 0.5694
# Epoch 25/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 4.2507 - accuracy: 0.6006 - val_loss: 4.3037 - val_accuracy: 0.5718
# Epoch 26/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 4.1326 - accuracy: 0.6110 - val_loss: 4.1903 - val_accuracy: 0.5774
# Epoch 27/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 4.0251 - accuracy: 0.6111 - val_loss: 4.0922 - val_accuracy: 0.5769
# Epoch 28/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 3.9213 - accuracy: 0.6160 - val_loss: 4.0060 - val_accuracy: 0.5738
# Epoch 29/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 3.8228 - accuracy: 0.6154 - val_loss: 3.9097 - val_accuracy: 0.5771
# Epoch 30/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 3.7339 - accuracy: 0.6162 - val_loss: 3.8331 - val_accuracy: 0.5771
# Epoch 31/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 3.6531 - accuracy: 0.6169 - val_loss: 3.7186 - val_accuracy: 0.5858
# Epoch 32/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 3.5627 - accuracy: 0.6219 - val_loss: 3.6631 - val_accuracy: 0.5831
# Epoch 33/150
# 27000/27000 [==============================] - 4s 130us/sample - loss: 3.4886 - accuracy: 0.6237 - val_loss: 3.6007 - val_accuracy: 0.5726
# Epoch 34/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 3.4206 - accuracy: 0.6226 - val_loss: 3.5095 - val_accuracy: 0.5826
# Epoch 35/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 3.3437 - accuracy: 0.6276 - val_loss: 3.4293 - val_accuracy: 0.5854
# Epoch 36/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 3.2750 - accuracy: 0.6241 - val_loss: 3.3864 - val_accuracy: 0.5839
# Epoch 37/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 3.1967 - accuracy: 0.6336 - val_loss: 3.3130 - val_accuracy: 0.5826
# Epoch 38/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 3.1338 - accuracy: 0.6331 - val_loss: 3.2528 - val_accuracy: 0.5797
# Epoch 39/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 3.0844 - accuracy: 0.6282 - val_loss: 3.1934 - val_accuracy: 0.5862
# Epoch 40/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 3.0192 - accuracy: 0.6353 - val_loss: 3.1198 - val_accuracy: 0.5913
# Epoch 41/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.9610 - accuracy: 0.6360 - val_loss: 3.0674 - val_accuracy: 0.5932
# Epoch 42/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.9170 - accuracy: 0.6324 - val_loss: 3.0159 - val_accuracy: 0.5879
# Epoch 43/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 2.8514 - accuracy: 0.6384 - val_loss: 2.9693 - val_accuracy: 0.5973
# Epoch 44/150
# 27000/27000 [==============================] - 4s 131us/sample - loss: 2.8055 - accuracy: 0.6394 - val_loss: 2.9178 - val_accuracy: 0.5918
# Epoch 45/150
# 27000/27000 [==============================] - 3s 130us/sample - loss: 2.7572 - accuracy: 0.6339 - val_loss: 2.8927 - val_accuracy: 0.5883
# Epoch 46/150
# 27000/27000 [==============================] - 4s 130us/sample - loss: 2.7133 - accuracy: 0.6373 - val_loss: 2.8304 - val_accuracy: 0.5986
# Epoch 47/150
# 27000/27000 [==============================] - 4s 132us/sample - loss: 2.6657 - accuracy: 0.6410 - val_loss: 2.7854 - val_accuracy: 0.5924
# Epoch 48/150
# 27000/27000 [==============================] - 4s 133us/sample - loss: 2.6243 - accuracy: 0.6363 - val_loss: 2.7487 - val_accuracy: 0.5933
# Epoch 49/150
# 27000/27000 [==============================] - 4s 130us/sample - loss: 2.5815 - accuracy: 0.6420 - val_loss: 2.7082 - val_accuracy: 0.5957
# Epoch 50/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.5384 - accuracy: 0.6454 - val_loss: 2.6628 - val_accuracy: 0.5965
# Epoch 51/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 2.4900 - accuracy: 0.6490 - val_loss: 2.6237 - val_accuracy: 0.6020
# Epoch 52/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 2.4696 - accuracy: 0.6418 - val_loss: 2.5933 - val_accuracy: 0.5950
# Epoch 53/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 2.4252 - accuracy: 0.6477 - val_loss: 2.5479 - val_accuracy: 0.5994
# Epoch 54/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 2.3967 - accuracy: 0.6442 - val_loss: 2.5228 - val_accuracy: 0.5970
# Epoch 55/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 2.3608 - accuracy: 0.6453 - val_loss: 2.4804 - val_accuracy: 0.6042
# Epoch 56/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 2.3280 - accuracy: 0.6487 - val_loss: 2.4530 - val_accuracy: 0.6041
# Epoch 57/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 2.3035 - accuracy: 0.6454 - val_loss: 2.4180 - val_accuracy: 0.6065
# Epoch 58/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 2.2663 - accuracy: 0.6501 - val_loss: 2.4043 - val_accuracy: 0.6003
# Epoch 59/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.2429 - accuracy: 0.6467 - val_loss: 2.3752 - val_accuracy: 0.6034
# Epoch 60/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.2210 - accuracy: 0.6453 - val_loss: 2.3385 - val_accuracy: 0.6034
# Epoch 61/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.1927 - accuracy: 0.6480 - val_loss: 2.3059 - val_accuracy: 0.6076
# Epoch 62/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.1599 - accuracy: 0.6523 - val_loss: 2.3147 - val_accuracy: 0.6017
# Epoch 63/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.1458 - accuracy: 0.6504 - val_loss: 2.2624 - val_accuracy: 0.6032
# Epoch 64/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 2.1180 - accuracy: 0.6494 - val_loss: 2.2567 - val_accuracy: 0.6024
# Epoch 65/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 2.0954 - accuracy: 0.6529 - val_loss: 2.2350 - val_accuracy: 0.6082
# Epoch 66/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.0786 - accuracy: 0.6509 - val_loss: 2.1869 - val_accuracy: 0.6122
# Epoch 67/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.0526 - accuracy: 0.6506 - val_loss: 2.1881 - val_accuracy: 0.6089
# Epoch 68/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 2.0313 - accuracy: 0.6553 - val_loss: 2.1582 - val_accuracy: 0.6056
# Epoch 69/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 2.0114 - accuracy: 0.6529 - val_loss: 2.1457 - val_accuracy: 0.6076
# Epoch 70/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.9961 - accuracy: 0.6524 - val_loss: 2.1217 - val_accuracy: 0.6089
# Epoch 71/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.9744 - accuracy: 0.6544 - val_loss: 2.1182 - val_accuracy: 0.6080
# Epoch 72/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.9588 - accuracy: 0.6515 - val_loss: 2.1039 - val_accuracy: 0.6065
# Epoch 73/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.9414 - accuracy: 0.6563 - val_loss: 2.0795 - val_accuracy: 0.6105
# Epoch 74/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.9257 - accuracy: 0.6562 - val_loss: 2.0726 - val_accuracy: 0.6101
# Epoch 75/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.9130 - accuracy: 0.6559 - val_loss: 2.0503 - val_accuracy: 0.6101
# Epoch 76/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.9031 - accuracy: 0.6541 - val_loss: 2.0447 - val_accuracy: 0.6068
# Epoch 77/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.8915 - accuracy: 0.6549 - val_loss: 2.0278 - val_accuracy: 0.6108
# Epoch 78/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 1.8824 - accuracy: 0.6497 - val_loss: 2.0061 - val_accuracy: 0.6101
# Epoch 79/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.8496 - accuracy: 0.6600 - val_loss: 1.9955 - val_accuracy: 0.6122
# Epoch 80/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.8511 - accuracy: 0.6538 - val_loss: 1.9765 - val_accuracy: 0.6139
# Epoch 81/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.8392 - accuracy: 0.6549 - val_loss: 1.9783 - val_accuracy: 0.6079
# Epoch 82/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.8269 - accuracy: 0.6570 - val_loss: 1.9507 - val_accuracy: 0.6139
# Epoch 83/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.8067 - accuracy: 0.6573 - val_loss: 1.9461 - val_accuracy: 0.6167
# Epoch 84/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.7998 - accuracy: 0.6557 - val_loss: 1.9232 - val_accuracy: 0.6167
# Epoch 85/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.7889 - accuracy: 0.6573 - val_loss: 1.9315 - val_accuracy: 0.6142
# Epoch 86/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.7763 - accuracy: 0.6620 - val_loss: 1.9190 - val_accuracy: 0.6138
# Epoch 87/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.7663 - accuracy: 0.6590 - val_loss: 1.9009 - val_accuracy: 0.6123
# Epoch 88/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.7545 - accuracy: 0.6646 - val_loss: 1.8933 - val_accuracy: 0.6178
# Epoch 89/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.7544 - accuracy: 0.6594 - val_loss: 1.8880 - val_accuracy: 0.6158
# Epoch 90/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.7478 - accuracy: 0.6569 - val_loss: 1.8735 - val_accuracy: 0.6146
# Epoch 91/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.7327 - accuracy: 0.6606 - val_loss: 1.8722 - val_accuracy: 0.6075
# Epoch 92/150
# 27000/27000 [==============================] - 3s 125us/sample - loss: 1.7258 - accuracy: 0.6605 - val_loss: 1.8615 - val_accuracy: 0.6141
# Epoch 93/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.7178 - accuracy: 0.6614 - val_loss: 1.8588 - val_accuracy: 0.6167
# Epoch 94/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.7069 - accuracy: 0.6638 - val_loss: 1.8459 - val_accuracy: 0.6099
# Epoch 95/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.7015 - accuracy: 0.6634 - val_loss: 1.8431 - val_accuracy: 0.6145
# Epoch 96/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.6913 - accuracy: 0.6629 - val_loss: 1.8354 - val_accuracy: 0.6144
# Epoch 97/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.6829 - accuracy: 0.6603 - val_loss: 1.8163 - val_accuracy: 0.6219
# Epoch 98/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.6857 - accuracy: 0.6601 - val_loss: 1.8214 - val_accuracy: 0.6139
# Epoch 99/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.6767 - accuracy: 0.6600 - val_loss: 1.8012 - val_accuracy: 0.6207
# Epoch 100/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.6738 - accuracy: 0.6590 - val_loss: 1.8024 - val_accuracy: 0.6208
# Epoch 101/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 1.6571 - accuracy: 0.6615 - val_loss: 1.7901 - val_accuracy: 0.6199
# Epoch 102/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 1.6571 - accuracy: 0.6604 - val_loss: 1.7872 - val_accuracy: 0.6169
# Epoch 103/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.6462 - accuracy: 0.6642 - val_loss: 1.7878 - val_accuracy: 0.6148
# Epoch 104/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.6429 - accuracy: 0.6614 - val_loss: 1.7764 - val_accuracy: 0.6177
# Epoch 105/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.6360 - accuracy: 0.6625 - val_loss: 1.7726 - val_accuracy: 0.6209
# Epoch 106/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.6363 - accuracy: 0.6628 - val_loss: 1.7682 - val_accuracy: 0.6191
# Epoch 107/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.6316 - accuracy: 0.6616 - val_loss: 1.7643 - val_accuracy: 0.6206
# Epoch 108/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.6204 - accuracy: 0.6643 - val_loss: 1.7662 - val_accuracy: 0.6231
# Epoch 109/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.6130 - accuracy: 0.6653 - val_loss: 1.7451 - val_accuracy: 0.6242
# Epoch 110/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.6085 - accuracy: 0.6657 - val_loss: 1.7390 - val_accuracy: 0.6217
# Epoch 111/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.6103 - accuracy: 0.6622 - val_loss: 1.7377 - val_accuracy: 0.6222
# Epoch 112/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.6047 - accuracy: 0.6649 - val_loss: 1.7334 - val_accuracy: 0.6242
# Epoch 113/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.6012 - accuracy: 0.6646 - val_loss: 1.7398 - val_accuracy: 0.6200
# Epoch 114/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5936 - accuracy: 0.6655 - val_loss: 1.7229 - val_accuracy: 0.6211
# Epoch 115/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5896 - accuracy: 0.6663 - val_loss: 1.7284 - val_accuracy: 0.6219
# Epoch 116/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5964 - accuracy: 0.6606 - val_loss: 1.7212 - val_accuracy: 0.6228
# Epoch 117/150
# 27000/27000 [==============================] - 3s 125us/sample - loss: 1.5864 - accuracy: 0.6616 - val_loss: 1.7202 - val_accuracy: 0.6204
# Epoch 118/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5824 - accuracy: 0.6673 - val_loss: 1.7112 - val_accuracy: 0.6248
# Epoch 119/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5731 - accuracy: 0.6663 - val_loss: 1.7019 - val_accuracy: 0.6271
# Epoch 120/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5733 - accuracy: 0.6651 - val_loss: 1.7046 - val_accuracy: 0.6242
# Epoch 121/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.5696 - accuracy: 0.6629 - val_loss: 1.7031 - val_accuracy: 0.6236
# Epoch 122/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5631 - accuracy: 0.6683 - val_loss: 1.6998 - val_accuracy: 0.6230
# Epoch 123/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5613 - accuracy: 0.6681 - val_loss: 1.7000 - val_accuracy: 0.6252
# Epoch 124/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5532 - accuracy: 0.6698 - val_loss: 1.6721 - val_accuracy: 0.6317
# Epoch 125/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 1.5530 - accuracy: 0.6709 - val_loss: 1.6889 - val_accuracy: 0.6254
# Epoch 126/150
# 27000/27000 [==============================] - 3s 129us/sample - loss: 1.5570 - accuracy: 0.6659 - val_loss: 1.6741 - val_accuracy: 0.6268
# Epoch 127/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.5523 - accuracy: 0.6652 - val_loss: 1.6965 - val_accuracy: 0.6231
# Epoch 128/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5445 - accuracy: 0.6689 - val_loss: 1.6735 - val_accuracy: 0.6251
# Epoch 129/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5394 - accuracy: 0.6691 - val_loss: 1.6742 - val_accuracy: 0.6261
# Epoch 130/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.5374 - accuracy: 0.6726 - val_loss: 1.6735 - val_accuracy: 0.6283
# Epoch 131/150
# 27000/27000 [==============================] - 3s 125us/sample - loss: 1.5416 - accuracy: 0.6684 - val_loss: 1.6637 - val_accuracy: 0.6310
# Epoch 132/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5340 - accuracy: 0.6680 - val_loss: 1.6792 - val_accuracy: 0.6259
# Epoch 133/150
# 27000/27000 [==============================] - 4s 130us/sample - loss: 1.5249 - accuracy: 0.6693 - val_loss: 1.6754 - val_accuracy: 0.6226
# Epoch 134/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.5227 - accuracy: 0.6694 - val_loss: 1.6638 - val_accuracy: 0.6242
# Epoch 135/150
# 27000/27000 [==============================] - 3s 125us/sample - loss: 1.5210 - accuracy: 0.6707 - val_loss: 1.6536 - val_accuracy: 0.6330
# Epoch 136/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5160 - accuracy: 0.6748 - val_loss: 1.6540 - val_accuracy: 0.6309
# Epoch 137/150
# 27000/27000 [==============================] - 4s 131us/sample - loss: 1.5221 - accuracy: 0.6703 - val_loss: 1.6558 - val_accuracy: 0.6273
# Epoch 138/150
# 27000/27000 [==============================] - 4s 132us/sample - loss: 1.5218 - accuracy: 0.6678 - val_loss: 1.6636 - val_accuracy: 0.6257
# Epoch 139/150
# 27000/27000 [==============================] - 4s 132us/sample - loss: 1.5158 - accuracy: 0.6699 - val_loss: 1.6591 - val_accuracy: 0.6243
# Epoch 140/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.5167 - accuracy: 0.6709 - val_loss: 1.6545 - val_accuracy: 0.6267
# Epoch 141/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.5080 - accuracy: 0.6728 - val_loss: 1.6443 - val_accuracy: 0.6301
# Epoch 142/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.5144 - accuracy: 0.6706 - val_loss: 1.6491 - val_accuracy: 0.6272
# Epoch 143/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.5040 - accuracy: 0.6720 - val_loss: 1.6528 - val_accuracy: 0.6259
# Epoch 144/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.5014 - accuracy: 0.6742 - val_loss: 1.6309 - val_accuracy: 0.6315
# Epoch 145/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.5078 - accuracy: 0.6669 - val_loss: 1.6361 - val_accuracy: 0.6328
# Epoch 146/150
# 27000/27000 [==============================] - 3s 127us/sample - loss: 1.4989 - accuracy: 0.6729 - val_loss: 1.6448 - val_accuracy: 0.6274
# Epoch 147/150
# 27000/27000 [==============================] - 3s 126us/sample - loss: 1.5041 - accuracy: 0.6726 - val_loss: 1.6285 - val_accuracy: 0.6287
# Epoch 148/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.4921 - accuracy: 0.6745 - val_loss: 1.6316 - val_accuracy: 0.6331
# Epoch 149/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.4917 - accuracy: 0.6741 - val_loss: 1.6288 - val_accuracy: 0.6300
# Epoch 150/150
# 27000/27000 [==============================] - 3s 128us/sample - loss: 1.4915 - accuracy: 0.6744 - val_loss: 1.6302 - val_accuracy: 0.6323

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylim(0, 1)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
plt.show()

# %% [markdown]
# ## MC Dropout

# %%
def MCDropout(rate):
    return tf.keras.layers.Lambda(lambda x: tf.keras.backend.dropout(x, level=rate))

model_mc = Sequential()
model_mc.add(Convolution2D(8,kernel_size=(3,3),padding="same", activation = 'relu',input_shape=(32,32,3)))
model_mc.add(MCDropout((0.5)))
model_mc.add(Convolution2D(8,kernel_size=(3,3),padding="same", activation = 'relu'))
model_mc.add(MCDropout((0.5)))
model_mc.add(MaxPooling2D((2,2)))
model_mc.add(Convolution2D(16,kernel_size=(3,3),padding="same", activation = 'relu'))
model_mc.add(MCDropout((0.5)))
model_mc.add(Convolution2D(16,kernel_size=(3,3),padding="same", activation = 'relu'))
model_mc.add(MCDropout((0.5)))
model_mc.add(MaxPooling2D((2,2)))
model_mc.add(Flatten())
model_mc.add(Dense(100, activation = 'relu'))
model_mc.add(MCDropout((0.5)))
model_mc.add(Dense(9, activation = 'softmax'))

model_mc.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])

model_mc.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0809 13:06:16.984932 139904071862144 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py:4081: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 32, 32, 8)         224
# _________________________________________________________________
# lambda (Lambda)              (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 32, 32, 8)         584
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 32, 32, 8)         0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 16, 16)        1168
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 16, 16, 16)        2320
# _________________________________________________________________
# lambda_3 (Lambda)            (None, 16, 16, 16)        0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               102500
# _________________________________________________________________
# lambda_4 (Lambda)            (None, 100)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 9)                 909
# =================================================================
# Total params: 107,705
# Trainable params: 107,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
for i in range(0,5):
  print(model_mc.predict(x_train[0:1])[0])
#we get a different pred at every run!
# Out:
# [7.8515553e-01 5.6014898e-05 4.7610414e-05 2.5310544e-02 7.9835624e-02
#  1.5470415e-03 7.0351220e-05 9.7169027e-02 1.0808327e-02]
# [9.7492617e-01 1.4905474e-03 4.7974871e-04 2.3831685e-04 2.5019588e-06
#  7.9650063e-06 2.2854103e-02 7.2241505e-07 5.4841966e-08]
# [1.4402533e-02 3.5839766e-04 6.9268630e-05 2.0459741e-03 8.0235749e-02
#  6.2093831e-04 8.4247965e-01 2.3335819e-04 5.9554044e-02]
# [8.4537431e-05 6.4160395e-01 1.0021467e-04 4.3775579e-03 5.2392708e-05
#  1.9035029e-05 3.0844605e-01 2.1159261e-02 2.4157006e-02]
# [0.00622412 0.00177255 0.03112852 0.06273282 0.12006496 0.01274875
#  0.21767563 0.5388032  0.00884943]

# %%
history=model_mc.fit(x_train, y_train,validation_data=(x_val,y_val), batch_size=128,epochs=150,verbose=1)
# Out:
# Train on 27000 samples, validate on 18000 samples
# Epoch 1/150
# 27000/27000 [==============================] - 3s 114us/sample - loss: 2.1406 - accuracy: 0.1666 - val_loss: 1.9794 - val_accuracy: 0.2333
# Epoch 2/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.8681 - accuracy: 0.2792 - val_loss: 1.7736 - val_accuracy: 0.3174
# Epoch 3/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.7137 - accuracy: 0.3488 - val_loss: 1.6622 - val_accuracy: 0.3646
# Epoch 4/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.6234 - accuracy: 0.3829 - val_loss: 1.5928 - val_accuracy: 0.3942
# Epoch 5/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.5803 - accuracy: 0.4031 - val_loss: 1.5768 - val_accuracy: 0.4009
# Epoch 6/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.5462 - accuracy: 0.4120 - val_loss: 1.5392 - val_accuracy: 0.4168
# Epoch 7/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.5171 - accuracy: 0.4243 - val_loss: 1.5158 - val_accuracy: 0.4244
# Epoch 8/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.4960 - accuracy: 0.4348 - val_loss: 1.4814 - val_accuracy: 0.4349
# Epoch 9/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.4688 - accuracy: 0.4469 - val_loss: 1.4417 - val_accuracy: 0.4574
# Epoch 10/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.4393 - accuracy: 0.4600 - val_loss: 1.4330 - val_accuracy: 0.4601
# Epoch 11/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.4227 - accuracy: 0.4666 - val_loss: 1.4144 - val_accuracy: 0.4678
# Epoch 12/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.3976 - accuracy: 0.4755 - val_loss: 1.4128 - val_accuracy: 0.4702
# Epoch 13/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.3774 - accuracy: 0.4841 - val_loss: 1.3911 - val_accuracy: 0.4828
# Epoch 14/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.3645 - accuracy: 0.4883 - val_loss: 1.3806 - val_accuracy: 0.4818
# Epoch 15/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.3533 - accuracy: 0.4934 - val_loss: 1.3779 - val_accuracy: 0.4915
# Epoch 16/150
# 27000/27000 [==============================] - 2s 93us/sample - loss: 1.3405 - accuracy: 0.5000 - val_loss: 1.3656 - val_accuracy: 0.4924
# Epoch 17/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.3314 - accuracy: 0.5045 - val_loss: 1.3548 - val_accuracy: 0.4928
# Epoch 18/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.3142 - accuracy: 0.5105 - val_loss: 1.3428 - val_accuracy: 0.4953
# Epoch 19/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.3083 - accuracy: 0.5134 - val_loss: 1.3305 - val_accuracy: 0.5096
# Epoch 20/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.2925 - accuracy: 0.5159 - val_loss: 1.3429 - val_accuracy: 0.5014
# Epoch 21/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.2889 - accuracy: 0.5181 - val_loss: 1.3373 - val_accuracy: 0.5076
# Epoch 22/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.2764 - accuracy: 0.5202 - val_loss: 1.3164 - val_accuracy: 0.5124
# Epoch 23/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.2798 - accuracy: 0.5224 - val_loss: 1.3240 - val_accuracy: 0.5086
# Epoch 24/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.2692 - accuracy: 0.5283 - val_loss: 1.3000 - val_accuracy: 0.5188
# Epoch 25/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.2589 - accuracy: 0.5294 - val_loss: 1.3447 - val_accuracy: 0.5023
# Epoch 26/150
# 27000/27000 [==============================] - 3s 94us/sample - loss: 1.2570 - accuracy: 0.5342 - val_loss: 1.3079 - val_accuracy: 0.5230
# Epoch 27/150
# 27000/27000 [==============================] - 3s 96us/sample - loss: 1.2425 - accuracy: 0.5316 - val_loss: 1.2860 - val_accuracy: 0.5287
# Epoch 28/150
# 27000/27000 [==============================] - 3s 95us/sample - loss: 1.2473 - accuracy: 0.5379 - val_loss: 1.2811 - val_accuracy: 0.5238
# Epoch 29/150
# 27000/27000 [==============================] - 3s 95us/sample - loss: 1.2382 - accuracy: 0.5431 - val_loss: 1.2822 - val_accuracy: 0.5263
# Epoch 30/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.2321 - accuracy: 0.5430 - val_loss: 1.2713 - val_accuracy: 0.5318
# Epoch 31/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.2236 - accuracy: 0.5445 - val_loss: 1.2623 - val_accuracy: 0.5337
# Epoch 32/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.2194 - accuracy: 0.5499 - val_loss: 1.2973 - val_accuracy: 0.5287
# Epoch 33/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.2113 - accuracy: 0.5485 - val_loss: 1.2755 - val_accuracy: 0.5308
# Epoch 34/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.2117 - accuracy: 0.5500 - val_loss: 1.2690 - val_accuracy: 0.5354
# Epoch 35/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.2078 - accuracy: 0.5494 - val_loss: 1.2619 - val_accuracy: 0.5376
# Epoch 36/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.2046 - accuracy: 0.5564 - val_loss: 1.2579 - val_accuracy: 0.5349
# Epoch 37/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.2008 - accuracy: 0.5533 - val_loss: 1.2476 - val_accuracy: 0.5397
# Epoch 38/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1945 - accuracy: 0.5595 - val_loss: 1.2491 - val_accuracy: 0.5402
# Epoch 39/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1877 - accuracy: 0.5585 - val_loss: 1.2487 - val_accuracy: 0.5431
# Epoch 40/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1844 - accuracy: 0.5581 - val_loss: 1.2337 - val_accuracy: 0.5452
# Epoch 41/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1827 - accuracy: 0.5608 - val_loss: 1.2347 - val_accuracy: 0.5448
# Epoch 42/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1696 - accuracy: 0.5645 - val_loss: 1.2591 - val_accuracy: 0.5433
# Epoch 43/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1768 - accuracy: 0.5664 - val_loss: 1.2319 - val_accuracy: 0.5498
# Epoch 44/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1652 - accuracy: 0.5694 - val_loss: 1.2341 - val_accuracy: 0.5500
# Epoch 45/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1633 - accuracy: 0.5681 - val_loss: 1.2335 - val_accuracy: 0.5418
# Epoch 46/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1573 - accuracy: 0.5697 - val_loss: 1.2264 - val_accuracy: 0.5531
# Epoch 47/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.1512 - accuracy: 0.5750 - val_loss: 1.2411 - val_accuracy: 0.5504
# Epoch 48/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.1528 - accuracy: 0.5737 - val_loss: 1.2419 - val_accuracy: 0.5454
# Epoch 49/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.1510 - accuracy: 0.5750 - val_loss: 1.2341 - val_accuracy: 0.5472
# Epoch 50/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1407 - accuracy: 0.5768 - val_loss: 1.2223 - val_accuracy: 0.5549
# Epoch 51/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1571 - accuracy: 0.5721 - val_loss: 1.2180 - val_accuracy: 0.5508
# Epoch 52/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1496 - accuracy: 0.5787 - val_loss: 1.2033 - val_accuracy: 0.5584
# Epoch 53/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1347 - accuracy: 0.5827 - val_loss: 1.2209 - val_accuracy: 0.5543
# Epoch 54/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1238 - accuracy: 0.5827 - val_loss: 1.2181 - val_accuracy: 0.5602
# Epoch 55/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1332 - accuracy: 0.5841 - val_loss: 1.2167 - val_accuracy: 0.5563
# Epoch 56/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1352 - accuracy: 0.5820 - val_loss: 1.2289 - val_accuracy: 0.5565
# Epoch 57/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1287 - accuracy: 0.5827 - val_loss: 1.2227 - val_accuracy: 0.5564
# Epoch 58/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1317 - accuracy: 0.5820 - val_loss: 1.2365 - val_accuracy: 0.5491
# Epoch 59/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1253 - accuracy: 0.5845 - val_loss: 1.2115 - val_accuracy: 0.5582
# Epoch 60/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1231 - accuracy: 0.5836 - val_loss: 1.2084 - val_accuracy: 0.5616
# Epoch 61/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1136 - accuracy: 0.5867 - val_loss: 1.2223 - val_accuracy: 0.5540
# Epoch 62/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1210 - accuracy: 0.5853 - val_loss: 1.2047 - val_accuracy: 0.5624
# Epoch 63/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1139 - accuracy: 0.5907 - val_loss: 1.1826 - val_accuracy: 0.5714
# Epoch 64/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1113 - accuracy: 0.5897 - val_loss: 1.2102 - val_accuracy: 0.5610
# Epoch 65/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.1151 - accuracy: 0.5936 - val_loss: 1.1985 - val_accuracy: 0.5634
# Epoch 66/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.1046 - accuracy: 0.5905 - val_loss: 1.1981 - val_accuracy: 0.5623
# Epoch 67/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0963 - accuracy: 0.5945 - val_loss: 1.1966 - val_accuracy: 0.5668
# Epoch 68/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0989 - accuracy: 0.5989 - val_loss: 1.1903 - val_accuracy: 0.5657
# Epoch 69/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.0977 - accuracy: 0.5940 - val_loss: 1.1979 - val_accuracy: 0.5644
# Epoch 70/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0909 - accuracy: 0.5978 - val_loss: 1.1900 - val_accuracy: 0.5669
# Epoch 71/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0891 - accuracy: 0.6012 - val_loss: 1.1946 - val_accuracy: 0.5703
# Epoch 72/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0865 - accuracy: 0.5940 - val_loss: 1.1942 - val_accuracy: 0.5684
# Epoch 73/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0873 - accuracy: 0.6013 - val_loss: 1.1912 - val_accuracy: 0.5643
# Epoch 74/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0920 - accuracy: 0.5963 - val_loss: 1.1921 - val_accuracy: 0.5704
# Epoch 75/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0872 - accuracy: 0.5954 - val_loss: 1.1816 - val_accuracy: 0.5716
# Epoch 76/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0802 - accuracy: 0.6010 - val_loss: 1.1855 - val_accuracy: 0.5702
# Epoch 77/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0857 - accuracy: 0.6020 - val_loss: 1.1956 - val_accuracy: 0.5696
# Epoch 78/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0866 - accuracy: 0.6001 - val_loss: 1.1895 - val_accuracy: 0.5682
# Epoch 79/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.0827 - accuracy: 0.6044 - val_loss: 1.1813 - val_accuracy: 0.5693
# Epoch 80/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.0807 - accuracy: 0.6007 - val_loss: 1.1800 - val_accuracy: 0.5703
# Epoch 81/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.0811 - accuracy: 0.6017 - val_loss: 1.1689 - val_accuracy: 0.5749
# Epoch 82/150
# 27000/27000 [==============================] - 2s 93us/sample - loss: 1.0787 - accuracy: 0.6045 - val_loss: 1.1827 - val_accuracy: 0.5739
# Epoch 83/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0788 - accuracy: 0.6038 - val_loss: 1.1668 - val_accuracy: 0.5803
# Epoch 84/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.0750 - accuracy: 0.6002 - val_loss: 1.1692 - val_accuracy: 0.5774
# Epoch 85/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.0692 - accuracy: 0.6100 - val_loss: 1.1672 - val_accuracy: 0.5736
# Epoch 86/150
# 27000/27000 [==============================] - 2s 88us/sample - loss: 1.0783 - accuracy: 0.6019 - val_loss: 1.1973 - val_accuracy: 0.5700
# Epoch 87/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0748 - accuracy: 0.6058 - val_loss: 1.1702 - val_accuracy: 0.5824
# Epoch 88/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0640 - accuracy: 0.6075 - val_loss: 1.1631 - val_accuracy: 0.5852
# Epoch 89/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0674 - accuracy: 0.6071 - val_loss: 1.1774 - val_accuracy: 0.5738
# Epoch 90/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0693 - accuracy: 0.6099 - val_loss: 1.1769 - val_accuracy: 0.5764
# Epoch 91/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0653 - accuracy: 0.6035 - val_loss: 1.1639 - val_accuracy: 0.5808
# Epoch 92/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0571 - accuracy: 0.6098 - val_loss: 1.1733 - val_accuracy: 0.5781
# Epoch 93/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0504 - accuracy: 0.6171 - val_loss: 1.2127 - val_accuracy: 0.5707
# Epoch 94/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0572 - accuracy: 0.6079 - val_loss: 1.1772 - val_accuracy: 0.5756
# Epoch 95/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.0615 - accuracy: 0.6094 - val_loss: 1.1804 - val_accuracy: 0.5756
# Epoch 96/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0555 - accuracy: 0.6117 - val_loss: 1.1713 - val_accuracy: 0.5799
# Epoch 97/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0485 - accuracy: 0.6136 - val_loss: 1.1673 - val_accuracy: 0.5816
# Epoch 98/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0509 - accuracy: 0.6118 - val_loss: 1.1738 - val_accuracy: 0.5781
# Epoch 99/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0538 - accuracy: 0.6130 - val_loss: 1.1824 - val_accuracy: 0.5714
# Epoch 100/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0472 - accuracy: 0.6155 - val_loss: 1.1709 - val_accuracy: 0.5775
# Epoch 101/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0570 - accuracy: 0.6081 - val_loss: 1.1659 - val_accuracy: 0.5786
# Epoch 102/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0554 - accuracy: 0.6142 - val_loss: 1.1720 - val_accuracy: 0.5787
# Epoch 103/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0507 - accuracy: 0.6139 - val_loss: 1.1783 - val_accuracy: 0.5754
# Epoch 104/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0477 - accuracy: 0.6128 - val_loss: 1.1843 - val_accuracy: 0.5761
# Epoch 105/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0532 - accuracy: 0.6120 - val_loss: 1.1615 - val_accuracy: 0.5822
# Epoch 106/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0391 - accuracy: 0.6204 - val_loss: 1.1612 - val_accuracy: 0.5766
# Epoch 107/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0477 - accuracy: 0.6134 - val_loss: 1.1725 - val_accuracy: 0.5770
# Epoch 108/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0428 - accuracy: 0.6178 - val_loss: 1.1714 - val_accuracy: 0.5843
# Epoch 109/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0534 - accuracy: 0.6129 - val_loss: 1.1814 - val_accuracy: 0.5811
# Epoch 110/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0480 - accuracy: 0.6143 - val_loss: 1.1638 - val_accuracy: 0.5810
# Epoch 111/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0451 - accuracy: 0.6151 - val_loss: 1.1561 - val_accuracy: 0.5807
# Epoch 112/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.0470 - accuracy: 0.6163 - val_loss: 1.1594 - val_accuracy: 0.5851
# Epoch 113/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0405 - accuracy: 0.6159 - val_loss: 1.1486 - val_accuracy: 0.5829
# Epoch 114/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.0454 - accuracy: 0.6160 - val_loss: 1.1658 - val_accuracy: 0.5763
# Epoch 115/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0396 - accuracy: 0.6193 - val_loss: 1.1776 - val_accuracy: 0.5732
# Epoch 116/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0366 - accuracy: 0.6153 - val_loss: 1.1758 - val_accuracy: 0.5784
# Epoch 117/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0417 - accuracy: 0.6138 - val_loss: 1.1670 - val_accuracy: 0.5775
# Epoch 118/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0439 - accuracy: 0.6175 - val_loss: 1.1677 - val_accuracy: 0.5811
# Epoch 119/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0412 - accuracy: 0.6163 - val_loss: 1.1813 - val_accuracy: 0.5787
# Epoch 120/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.0383 - accuracy: 0.6197 - val_loss: 1.1746 - val_accuracy: 0.5804
# Epoch 121/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0303 - accuracy: 0.6236 - val_loss: 1.1672 - val_accuracy: 0.5808
# Epoch 122/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0350 - accuracy: 0.6206 - val_loss: 1.1652 - val_accuracy: 0.5801
# Epoch 123/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.0352 - accuracy: 0.6219 - val_loss: 1.1688 - val_accuracy: 0.5844
# Epoch 124/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0384 - accuracy: 0.6210 - val_loss: 1.1811 - val_accuracy: 0.5756
# Epoch 125/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0342 - accuracy: 0.6183 - val_loss: 1.1819 - val_accuracy: 0.5798
# Epoch 126/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0437 - accuracy: 0.6168 - val_loss: 1.1694 - val_accuracy: 0.5870
# Epoch 127/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0299 - accuracy: 0.6211 - val_loss: 1.1550 - val_accuracy: 0.5864
# Epoch 128/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0239 - accuracy: 0.6233 - val_loss: 1.1644 - val_accuracy: 0.5819
# Epoch 129/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0280 - accuracy: 0.6241 - val_loss: 1.1757 - val_accuracy: 0.5781
# Epoch 130/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0338 - accuracy: 0.6218 - val_loss: 1.1528 - val_accuracy: 0.5874
# Epoch 131/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0240 - accuracy: 0.6204 - val_loss: 1.1737 - val_accuracy: 0.5824
# Epoch 132/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.0267 - accuracy: 0.6230 - val_loss: 1.1639 - val_accuracy: 0.5853
# Epoch 133/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0245 - accuracy: 0.6239 - val_loss: 1.1538 - val_accuracy: 0.5852
# Epoch 134/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0173 - accuracy: 0.6238 - val_loss: 1.1653 - val_accuracy: 0.5858
# Epoch 135/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.0210 - accuracy: 0.6248 - val_loss: 1.1580 - val_accuracy: 0.5832
# Epoch 136/150
# 27000/27000 [==============================] - 2s 89us/sample - loss: 1.0205 - accuracy: 0.6243 - val_loss: 1.1684 - val_accuracy: 0.5877
# Epoch 137/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0266 - accuracy: 0.6224 - val_loss: 1.1674 - val_accuracy: 0.5826
# Epoch 138/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0259 - accuracy: 0.6226 - val_loss: 1.1568 - val_accuracy: 0.5869
# Epoch 139/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0255 - accuracy: 0.6188 - val_loss: 1.1519 - val_accuracy: 0.5882
# Epoch 140/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0219 - accuracy: 0.6268 - val_loss: 1.1611 - val_accuracy: 0.5853
# Epoch 141/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0292 - accuracy: 0.6241 - val_loss: 1.1558 - val_accuracy: 0.5847
# Epoch 142/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0133 - accuracy: 0.6247 - val_loss: 1.1648 - val_accuracy: 0.5864
# Epoch 143/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.0227 - accuracy: 0.6236 - val_loss: 1.1518 - val_accuracy: 0.5855
# Epoch 144/150
# 27000/27000 [==============================] - 3s 93us/sample - loss: 1.0085 - accuracy: 0.6306 - val_loss: 1.1481 - val_accuracy: 0.5918
# Epoch 145/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.0147 - accuracy: 0.6260 - val_loss: 1.1717 - val_accuracy: 0.5805
# Epoch 146/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0241 - accuracy: 0.6236 - val_loss: 1.1617 - val_accuracy: 0.5909
# Epoch 147/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.0146 - accuracy: 0.6272 - val_loss: 1.1527 - val_accuracy: 0.5861
# Epoch 148/150
# 27000/27000 [==============================] - 2s 92us/sample - loss: 1.0164 - accuracy: 0.6259 - val_loss: 1.1513 - val_accuracy: 0.5884
# Epoch 149/150
# 27000/27000 [==============================] - 2s 91us/sample - loss: 1.0113 - accuracy: 0.6291 - val_loss: 1.1557 - val_accuracy: 0.5877
# Epoch 150/150
# 27000/27000 [==============================] - 2s 90us/sample - loss: 1.0128 - accuracy: 0.6289 - val_loss: 1.1478 - val_accuracy: 0.5908

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylim(0, 1)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='lower right')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper right')
plt.show()

# %% [markdown]
# ### Acc on the lables in the train set for all three models
# VI and MC 50 preds und then argmax of mean

# %%
known_idx=np.where(y_test!=7)[0]
print(len(known_idx))
x_test_known = x_test[known_idx]
y_test_known = y_test[known_idx]

unknown_idx=np.where(y_test==7)[0]
print(len(unknown_idx))
x_test_unknown = x_test[unknown_idx]
y_test_unknown = y_test[unknown_idx]
# Out:
# 9000
# 1000

# %%
pred=np.argmax(model.predict(x_test_known),axis=1)
pred_label=np.array([labels_no_horse[np.int(pred[i])] for i in range(0,len(pred))])
true_label=np.array([labels[np.int(y_test_known[i])] for i in range(0,len(y_test_known))])
print("test_acc_on_known_lables =",np.sum(pred_label==true_label)/len(true_label) )
test_acc_known = np.sum(pred_label==true_label)/len(true_label)
# Out:
# test_acc_on_known_lables = 0.6591111111111111

# %%
from tqdm import tqdm_notebook as tqdm

# %%
# 50 pred and then mean and argmax for the val set
SET=x_test_known
pred=np.zeros((len(SET),1))
for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_vi.predict(multi_img)
  pred[i]=np.argmax(np.mean(preds,axis=0))#mean over n runs of every proba class
# Out:
# HBox(children=(IntProgress(value=0, max=9000), HTML(value='')))

# %%
pred_label=np.array([labels_no_horse[np.int(pred[i])] for i in range(0,len(pred))])
true_label=np.array([labels[np.int(y_test_known[i])] for i in range(0,len(y_test_known))])
print("test_acc_on_known_lables =",np.sum(pred_label==true_label)/len(true_label) )
test_acc_known_vi = np.sum(pred_label==true_label)/len(true_label)
# Out:
# test_acc_on_known_lables = 0.6852222222222222

# %%
# 50 pred and then mean and argmax for the val set
SET=x_test_known
pred=np.zeros((len(SET),1))
for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_mc.predict(multi_img)
  pred[i]=np.argmax(np.mean(preds,axis=0))#mean over n runs of every proba class
# Out:
# HBox(children=(IntProgress(value=0, max=9000), HTML(value='')))

# %%
pred_label=np.array([labels_no_horse[np.int(pred[i])] for i in range(0,len(pred))])
true_label=np.array([labels[np.int(y_test_known[i])] for i in range(0,len(y_test_known))])
print("test_acc_on_known_lables =",np.sum(pred_label==true_label)/len(true_label) )
test_acc_known_mc = np.sum(pred_label==true_label)/len(true_label)
# Out:
# test_acc_on_known_lables = 0.676

# %%
import pandas as pd
pd.DataFrame(np.column_stack([test_acc_known,test_acc_known_vi,test_acc_known_mc]), index=['test acc on known labels'],columns=['baseline','VI','MC'])
# Out:
#                           baseline        VI     MC
# test acc on known labels  0.659111  0.685222  0.676

# %%
print("test_acc =" ,np.sum(pred_mean_label==true_label)/len(true_label))
#test acc
# Out:
# test_acc = 0.6215

# %%
pred=np.argmax(model.predict(x_test_unknown),axis=1)
pred_label=np.array([labels_no_horse[np.int(pred[i])] for i in range(0,len(pred))])

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,3,1)
pred=np.argmax(model.predict(x_test_unknown),axis=1)
pred_label=np.array([labels_no_horse[np.int(pred[i])] for i in range(0,len(pred))])
plt.bar(np.unique(pred_label,return_counts=True)[0],np.unique(pred_label,return_counts=True)[1])
plt.xticks(rotation=45)
plt.title("baseline horses predicted as:")
plt.subplot(1,3,2)
SET=x_test_unknown
pred=np.zeros((len(SET),1))
for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_vi.predict(multi_img)
  pred[i]=np.argmax(np.mean(preds,axis=0))#mean over n runs of every proba class
pred_label=np.array([labels_no_horse[np.int(pred[i])] for i in range(0,len(pred))])
plt.bar(np.unique(pred_label,return_counts=True)[0],np.unique(pred_label,return_counts=True)[1])
plt.xticks(rotation=45)
plt.title("VI horses predicted as:")
plt.subplot(1,3,3)
SET=x_test_unknown
pred=np.zeros((len(SET),1))
for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_mc.predict(multi_img)
  pred[i]=np.argmax(np.mean(preds,axis=0))#mean over n runs of every proba class
pred_label=np.array([labels_no_horse[np.int(pred[i])] for i in range(0,len(pred))])
plt.bar(np.unique(pred_label,return_counts=True)[0],np.unique(pred_label,return_counts=True)[1])
plt.xticks(rotation=45)
plt.title("MC horses predicted as:")
plt.show()
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
## look at the means sd and entropy of the true horses of the testset,
## here we want to see a hight uncertainty

pred=model.predict(x_test_unknown)
pred_uk=np.max(pred,axis=1)

plt.figure(figsize=(12,12))
plt.subplot(3,3,1)
plt.hist(pred_uk,bins=30)
plt.title("baseline max predicted mean p of unknown class")
plt.subplot(3,3,2)
plt.axis("off")
plt.subplot(3,3,3)
plt.axis("off")

SET=x_test_unknown
pred=np.zeros((len(SET),1))
pred_std_uk=np.zeros((len(SET),1))
pred_means_uk=np.zeros((len(SET),9))
entropy_uk = np.zeros((len(SET),1))

for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_vi.predict(multi_img)
  pred_means_uk[i]= np.mean(preds,axis=0)
  pred[i]=np.argmax(np.mean(preds,axis=0))
  pred_std_uk[i]= np.sqrt(np.sum(np.var(preds, axis=0)))
  entropy_uk[i] = -np.sum( pred_means_uk[i] * np.log2(pred_means_uk[i] + 1E-14)) #Numerical Stability

plt.subplot(3,3,4)
plt.hist(np.max(pred_means_uk,axis=1),bins=30)
plt.title("VI max predicted mean p of unknown class")
plt.subplot(3,3,5)
plt.hist(pred_std_uk,bins=30)
plt.title("VI std of unknown class")
plt.subplot(3,3,6)
plt.hist(entropy_uk,bins=30)
plt.title("VI entropy of unknown class")



SET=x_test_unknown
pred=np.zeros((len(SET),1))
pred_std_uk=np.zeros((len(SET),1))
pred_means_uk=np.zeros((len(SET),9))
entropy_uk = np.zeros((len(SET),1))

for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_mc.predict(multi_img)
  pred_means_uk[i]= np.mean(preds,axis=0)
  pred[i]=np.argmax(np.mean(preds,axis=0))
  pred_std_uk[i]= np.sqrt(np.sum(np.var(preds, axis=0)))
  entropy_uk[i] = -np.sum( pred_means_uk[i] * np.log2(pred_means_uk[i] + 1E-14)) #Numerical Stability

plt.subplot(3,3,7)
plt.hist(np.max(pred_means_uk,axis=1),bins=30)
plt.title("MC max predicted mean p of unknown class")
plt.subplot(3,3,8)
plt.hist(pred_std_uk,bins=30)
plt.title("MC std of unknown class")
plt.subplot(3,3,9)
plt.hist(entropy_uk,bins=30)
plt.title("MC entropy of unknown class")
plt.show()
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
## look at the means sd and entropy of the known classes of the testset,
## here we want to see a low uncertainty

pred=model.predict(x_test_known)
pred_uk=np.max(pred,axis=1)

plt.figure(figsize=(12,12))
plt.subplot(3,3,1)
plt.hist(pred_uk,bins=30)
plt.title("baseline max predicted mean p of known class")
plt.subplot(3,3,2)
plt.axis("off")
plt.subplot(3,3,3)
plt.axis("off")

SET=x_test_known
pred=np.zeros((len(SET),1))
pred_std_uk=np.zeros((len(SET),1))
pred_means_uk=np.zeros((len(SET),9))
entropy_uk = np.zeros((len(SET),1))

for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_vi.predict(multi_img)
  pred_means_uk[i]= np.mean(preds,axis=0)
  pred[i]=np.argmax(np.mean(preds,axis=0))
  pred_std_uk[i]= np.sqrt(np.sum(np.var(preds, axis=0)))
  entropy_uk[i] = -np.sum( pred_means_uk[i] * np.log2(pred_means_uk[i] + 1E-14)) #Numerical Stability

plt.subplot(3,3,4)
plt.hist(np.max(pred_means_uk,axis=1),bins=30)
plt.title("VI max predicted mean p of known class")
plt.subplot(3,3,5)
plt.hist(pred_std_uk,bins=30)
plt.title("VI std of known class")
plt.subplot(3,3,6)
plt.hist(entropy_uk,bins=30)
plt.title("VI entropy of known class")



SET=x_test_known
pred=np.zeros((len(SET),1))
pred_std_uk=np.zeros((len(SET),1))
pred_means_uk=np.zeros((len(SET),9))
entropy_uk = np.zeros((len(SET),1))

for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_mc.predict(multi_img)
  pred_means_uk[i]= np.mean(preds,axis=0)
  pred[i]=np.argmax(np.mean(preds,axis=0))
  pred_std_uk[i]= np.sqrt(np.sum(np.var(preds, axis=0)))
  entropy_uk[i] = -np.sum( pred_means_uk[i] * np.log2(pred_means_uk[i] + 1E-14)) #Numerical Stability

plt.subplot(3,3,7)
plt.hist(np.max(pred_means_uk,axis=1),bins=30)
plt.title("MC max predicted mean p of known class")
plt.subplot(3,3,8)
plt.hist(pred_std_uk,bins=30)
plt.title("MC std of known class")
plt.subplot(3,3,9)
plt.hist(entropy_uk,bins=30)
plt.title("MC entropy of known class")
plt.show()
# Out:
# HBox(children=(IntProgress(value=0, max=9000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=9000), HTML(value='')))

# %% [markdown]
# ## Filter our preds with pmax and p_mean

# %%
pred=model.predict(x_test)
pred=np.max(pred,axis=1)
certainty_idx = np.argsort(pred.reshape(len(pred)))
certainty_idx = certainty_idx[::-1]#reverse
print(certainty_idx[0:10])
print(pred[certainty_idx[0:10]])
# Out:
# [1833 5526 9619 5989 2156 5720 8195 9814 8931 5124]
# [1.         1.         0.9999999  0.9999999  0.99999976 0.9999995
#  0.9999995  0.9999994  0.9999987  0.9999987 ]

# %%
acc_nbest
# Out:
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
pred=model.predict(x_test)
pred=np.max(pred,axis=1)
certainty_idx = np.argsort(pred.reshape(len(pred)))
certainty_idx = certainty_idx[::-1]#reverse


pred=model.predict(x_test)
acc_nbest = np.zeros((2000))
for j in tqdm(range(0,2000)):
  pred_am=np.argmax(pred[certainty_idx[0:j]],axis=1)
  pred_label=np.array([labels_no_horse[np.int(pred_am[i])] for i in range(0,len(pred_am))])
  tmp=y_test[certainty_idx[0:j]]
  true_label=np.array([labels[np.int(tmp[i])] for i in range(0,len(tmp))])
  acc_nbest[j]=(np.sum(pred_label==true_label)/len(pred_label))

plt.plot(acc_nbest,c="black")
plt.title('Model Accuracy using mean as a filter')
plt.ylabel('accuracy')
plt.xlabel('Number of Examples taken')


SET=x_test
pred=np.zeros((len(SET),1))
pred_means_uk=np.zeros((len(SET),9))

for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_vi.predict(multi_img)
  pred_means_uk[i]= np.mean(preds,axis=0)

pred=np.max(pred_means_uk,axis=1)
certainty_idx = np.argsort(pred.reshape(len(pred)))
certainty_idx = certainty_idx[::-1]#reverse
print(certainty_idx[0:10])
print(pred[certainty_idx[0:10]])

acc_nbest = np.zeros((2000))
for j in tqdm(range(0,2000)):
  pred_am=np.argmax(pred_means_uk[certainty_idx[0:j]],axis=1)
  pred_label=np.array([labels_no_horse[np.int(pred_am[i])] for i in range(0,len(pred_am))])
  tmp=y_test[certainty_idx[0:j]]
  true_label=np.array([labels[np.int(tmp[i])] for i in range(0,len(tmp))])
  acc_nbest[j]=(np.sum(pred_label==true_label)/len(pred_label))
  
plt.plot(acc_nbest,c="red")



SET=x_test
pred=np.zeros((len(SET),1))
pred_means_uk=np.zeros((len(SET),9))

for i in tqdm(range(0,len(SET))):
  multi_img=np.tile(SET[i],(50,1,1,1))
  preds=model_mc.predict(multi_img)
  pred_means_uk[i]= np.mean(preds,axis=0)

pred=np.max(pred_means_uk,axis=1)
certainty_idx = np.argsort(pred.reshape(len(pred)))
certainty_idx = certainty_idx[::-1]#reverse
print(certainty_idx[0:10])
print(pred[certainty_idx[0:10]])

acc_nbest = np.zeros((2000))
for j in tqdm(range(0,2000)):
  pred_am=np.argmax(pred_means_uk[certainty_idx[0:j]],axis=1)
  pred_label=np.array([labels_no_horse[np.int(pred_am[i])] for i in range(0,len(pred_am))])
  tmp=y_test[certainty_idx[0:j]]
  true_label=np.array([labels[np.int(tmp[i])] for i in range(0,len(tmp))])
  acc_nbest[j]=(np.sum(pred_label==true_label)/len(pred_label))
  
plt.plot(acc_nbest,c="blue")
# Out:
# HBox(children=(IntProgress(value=0, max=2000), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in long_scalars
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# [3982 6104 7715 8150 3691 6672  252 2445 1915 5720]
# [0.99976754 0.9997043  0.99966997 0.99965966 0.99963117 0.99957705
#  0.9992975  0.99921179 0.99910378 0.99903291]
# HBox(children=(IntProgress(value=0, max=2000), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:43: RuntimeWarning: invalid value encountered in long_scalars
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# [9814 5935  235 9138 9614 9565 9531 2052 8150 4671]
# [0.98692924 0.98664939 0.98645109 0.98534089 0.9852531  0.98094934
#  0.98066038 0.97959548 0.97898889 0.97877854]
# HBox(children=(IntProgress(value=0, max=2000), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:70: RuntimeWarning: invalid value encountered in long_scalars
